# %%
from bs4 import BeautifulSoup
import requests, openpyxl

excel = openpyxl.Workbook()
print(excel.sheetnames)
sheet = excel.active
sheet.title = 'Top Rated Movies'
print(excel.sheetnames)
sheet.append(['Movie Rank', 'Movie Name', 'Year of Released', 'IMDb Rating'])

try: 
    url = requests. get('https://www.imdb.com/chart/top/')
    url.raise_for_status()
    
    soup = BeautifulSoup(url.text, 'html.parser')
    
    movies = soup.find('tbody', class_ = 'lister-list').find_all('tr')
    
    for movie in movies:
        name = movie.find('td', class_ = 'titleColumn').a.text
        rank = movie.find('td', class_ = 'titleColumn').get_text(strip = True).split('.')[0]
        year = movie.find('td', class_ = 'titleColumn').span.text.strip('()')
        rating = movie.find('td', class_ = 'ratingColumn imdbRating').strong.text
        
        print(rank, name, year, rating)
        sheet.append([rank, name, year, rating])
        
except Exception as e:
    print(e)
    
excel.save('IMDb Top 250 Movies Ratings.xlsx')
# Out:
# ['Sheet']
# ['Top Rated Movies']
# 1 쇼생크 탈출 1994 9.2
# 2 Daeboo 1972 9.2
# 3 다크 나이트 2008 9.0
# 4 The Godfather Part II 1974 9.0
# 5 12명의 성난 사람들 1957 9.0
# 6 쉰들러 리스트 1993 8.9
# 7 반지의 제왕: 왕의 귀환 2003 8.9
# 8 펄프 픽션 1994 8.8
# 9 반지의 제왕: 반지 원정대 2001 8.8
# 10 석양의 무법자 1966 8.8
# 11 포레스트 검프 1994 8.8
# 12 파이트 클럽 1999 8.7
# 13 The Lord of the Rings: The Two Towers 2002 8.7
# 14 인셉션 2010 8.7
# 15 스타워즈 에피소드 5 - 제국의 역습 1980 8.7
# 16 매트릭스 1999 8.7
# 17 좋은 친구들 1990 8.7
# 18 뻐꾸기 둥지 위로 날아간 새 1975 8.6
# 19 세븐 1995 8.6
# 20 7인의 사무라이 1954 8.6
# 21 멋진 인생 1946 8.6
# 22 양들의 침묵 1991 8.6
# 23 시티 오브 갓 2002 8.6
# 24 라이언 일병 구하기 1998 8.6
# 25 La vita è bella 1997 8.6
# 26 인터스텔라 2014 8.6
# 27 그린 마일 1999 8.6
# 28 Star Wars 1977 8.6
# 29 Terminator 2: Judgment Day 1991 8.5
# 30 빽 투 더 퓨쳐 1985 8.5
# 31 센과 치히로의 행방불명 2001 8.5
# 32 싸이코 1960 8.5
# 33 피아니스트 2002 8.5
# 34 Gisaengchung 2019 8.5
# 35 레옹 1994 8.5
# 36 라이온 킹 1994 8.5
# 37 글래디에이터 2000 8.5
# 38 아메리칸 히스토리 X 1998 8.5
# 39 디파티드 2006 8.5
# 40 유주얼 서스펙트 1995 8.5
# 41 프레스티지 2006 8.5
# 42 위플래쉬 2014 8.5
# 43 카사블랑카 1942 8.5
# 44 Seppuku 1962 8.5
